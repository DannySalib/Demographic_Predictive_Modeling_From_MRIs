# %%
import sys 
import os 
# Add the project root to sys.path
sys.path.append(os.path.abspath('../'))

from Util.Nifti.NiftiHandler import NiftiHandler
import nibabel as nib

func = nib.load(r'..\Data\func\sub-pixar001.nii.gz')
func.shape
# Out:
# (64, 64, 32, 168)

# %%
nifti_handler = NiftiHandler(func)
nifti_handler.img = nifti_handler.get_roi_img('Prefrontal Cortex')
nifti_handler.show_img(2, 2, time=0)
# Out:
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\danie\nilearn_data\fsl
# c:\Users\danie\Documents\Demographic_Predictive_Modeling_From_MRIs\Util\Nifti\NiftiHandler.py:115: FutureWarning: 'force_resample' will be set to 'True' by default in Nilearn 0.13.0.
# Use 'force_resample=True' to suppress this warning.
#   return resample_to_img(
# c:\Users\danie\Documents\Demographic_Predictive_Modeling_From_MRIs\Util\Nifti\NiftiHandler.py:115: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   return resample_to_img(
